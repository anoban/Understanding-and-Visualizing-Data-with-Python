# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# # ___Graphical Summary of Quantitative Data: Box plots___
# -------------

# %%
# Box plots are essentially a visual representation of the 5 number summary.

# %%
# A box plot starts with our quartiles Q1 and Q3.
# These two form the edges of the box.
# The length of the box is the IQR.

# Median is marked in the middle of the box.
# Minimum & maximum are marked with the whiskers.

# %%
heights = stats.skewnorm.rvs(a = 100, loc = 160, scale = 50, size = 1000)

# %%
# By default, whiskers in box plot are drawn at (Q1 - 1.5 IQR) and at (Q3 + 1.5 IQR)

plt.boxplot(heights, vert = False)
plt.grid()
plt.show()

# %%
# Customize the whiskers to be drawn at the 0th and 100th quantile  i.e min and max.

plt.boxplot(heights, vert = False, whis = (0, 100))
plt.tight_layout()
plt.grid()
plt.show()

# %%
bpressure = stats.skewnorm.rvs(a = 10, loc = 150, scale = 15, size = 2000)

# %%
plt.hist(bpressure, bins = 30, rwidth = 0.9, color = "blue")
plt.show()

# %%
# Whiskers here mark the 0th and 100th quantiles.

q1q3 = np.quantile(bpressure, [.25, .75])

fig, axes = plt.subplots()
fig.set_size_inches(10, 3)
axes.boxplot(bpressure, vert = False, whis = (0, 100))
axes.vlines(x = q1q3, ymin = 0.5, ymax = 1.5, colors = "red")
axes.fill_betweenx(y = [0.5, 1.5], x1 = [q1q3[0], q1q3[0]], x2 = [q1q3[1], q1q3[1]], color = "yellow", alpha = 0.05)
plt.show()

# %%
# Skewed distributions give asymmetric boxplots.
# While bell shaped distributions (symmetric) give symmetric boxplots.

# %%
# Symmetric boxplots

x = np.random.normal(loc = 100, scale = 10, size = 2000)
fig, axes = plt.subplots()
fig.set_size_inches(10, 3)
axes.boxplot(x, vert = False, whis = (0, 100))
plt.show()

# %%
# Boxplots also help identify outliers.

x = stats.skewnorm.rvs(a = -100, loc = 1000, scale = 100, size = 2000)
q1_minus_1point5_stddev = np.quantile(x, 0.25) - (1.5 * x.std())
outliers = x[np.where(x < q1_minus_1point5_stddev)[0]]


fig, axes = plt.subplots()
fig.set_size_inches(10, 3)
axes.boxplot(x, vert = False)
axes.plot(outliers, np.repeat(1, len(outliers)), color = "red", marker = "o", linestyle = "none")
plt.show()

# %% [markdown]
# ## ___Shortcomings of Boxplots___

# %%
# Here, we clearly see two different clusters.

x = np.random.normal(loc = 100, scale = 10, size = 500)
y = np.random.normal(loc = 300, scale = 10, size = 500)
x = np.append(x, y)

plt.hist(x, bins = 25, color = "blue", rwidth = 0.9)
plt.show()

# %%
# Will these clusters reflect in boxplots?

fig, axes = plt.subplots()
fig.set_size_inches(10, 3)
axes.boxplot(x, vert = False)
plt.show()

# %%
# Oopsies.
# Our boxplot fails to show the gap present between the data points.

# %% [markdown]
# # ___Boxplots can hide gaps and clusters.___

# %% [markdown]
# ![blood pressure](./systolicbp.png)

# %%
# The abobe boxplot shows side by side comparison of systolic and diastolic blood pressures of males and females by age.
# Generally both the systolic and diastolic blood pressures increase with age in both sexes.
# Systolic blood pressure is always higher than the diastolic blood pressure in all age groups and all genders.
# Females tend to have lower blood pressures compared to their male counterparts of the same age group.

# %% [markdown]
# ## ___Boxplots are good for side by side comparisons of a set of variables___
